# %%
import matplotlib.pyplot as plt
import cv2 
img = cv2.imread('img1.png')
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.title('In BGR format')
plt.imshow(img)

# %% [markdown]
# cv2.imread() reads image in BGR , therefore converting it into RGB for matplotplib.pyplot

# %%
## bgr to rgb
x = img 
img2[:,:,0] = x[:,:,2]
img2[:,:,2] = x[:,:,0]
img2[:,:,1] = x[:,:,1]

plt.figure(figsize=(10,6))
plt.title('Original Image')
plt.imshow(img2)
img2[0]
# Out:
# array([[136, 127, 145],
#        [137, 127, 144],
#        [137, 127, 144],
#        ...,
#        [132, 123, 142],
#        [131, 124, 141],
#        [130, 124, 142]], dtype=uint8)

# %% [markdown]
# ### Luminosity Method
# $0.21R+0.72G+0.07B $

# %%
plt.figure(figsize=(10,6))
plt.imshow((0.21*img2[:,:,0] + 0.72*img2[:,:,1] + 0.07*img2[:,:,2]),cmap='gray')
plt.title('Grayscale Image')
# Out:
# Text(0.5, 1.0, 'Grayscale Image')

# %% [markdown]
# ### Average method
# $\frac{ R + G + B }{  3}$

# %%
plt.figure(figsize=(10,6))
plt.imshow((img[:,:,0] + img[:,:,1] + img[:,:,2]) / 3,cmap='gray')
plt.title('Grayscale Image')
# Out:
# Text(0.5, 1.0, 'Grayscale Image')
